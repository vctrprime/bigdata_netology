# %%
import pandas as pd

# %%
data = pd.read_csv('abalone.csv')

# %%
data['Sex']
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
# 5       I
# 6       F
# 7       F
# 8       M
# 9       F
# 10      F
# 11      M
# 12      M
# 13      F
# 14      F
# 15      M
# 16      I
# 17      F
# 18      M
# 19      M
# 20      M
# 21      I
# 22      F
# 23      F
# 24      F
# 25      F
# 26      F
# 27      M
# 28      M
# 29      M
#        ..
# 4147    M
# 4148    M
# 4149    I
# 4150    I
# 4151    I
# 4152    I
# 4153    I
# 4154    I
# 4155    I
# 4156    M
# 4157    M
# 4158    I
# 4159    F
# 4160    F
# 4161    F
# 4162    M
# 4163    I
# 4164    I
# 4165    I
# 4166    I
# 4167    M
# 4168    F
# 4169    M
# 4170    M
# 4171    M
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: Sex, Length: 4177, dtype: object

# %%
#выбор строк от 5 до 9, столбцы от 4 до 7
data.iloc[5:10, 4:8]
# Out:
#    Whole weight  Shucked weight  Viscera weight  Shell weight
# 5        0.3515          0.1410          0.0775         0.120
# 6        0.7775          0.2370          0.1415         0.330
# 7        0.7680          0.2940          0.1495         0.260
# 8        0.5095          0.2165          0.1125         0.165
# 9        0.8945          0.3145          0.1510         0.320

# %%
#все строки после 1000
data.iloc[1000:]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1000   F   0.595     0.450   0.150        1.1140          0.5865
# 1001   M   0.595     0.475   0.165        1.2130          0.6210
# 1002   F   0.595     0.460   0.140        1.0045          0.4655
# 1003   M   0.595     0.455   0.150        1.0440          0.5180
# 1004   F   0.605     0.490   0.150        1.1345          0.5265
# 1005   M   0.605     0.475   0.155        1.1610          0.5720
# 1006   M   0.605     0.470   0.165        1.2315          0.6025
# 1007   M   0.610     0.470   0.150        1.1625          0.5650
# 1008   M   0.610     0.475   0.155        1.1680          0.5540
# 1009   F   0.615     0.480   0.160        1.2525          0.5850
# 1010   F   0.620     0.510   0.180        1.3315          0.5940
# 1011   F   0.625     0.480   0.170        1.3525          0.6235
# 1012   M   0.625     0.490   0.175        1.3325          0.5705
# ...

# %%
#выборка где колец больше 10
data[data['Rings'] > 10]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 10     F   0.525     0.380   0.140        0.6065          0.1940
# 12     M   0.490     0.380   0.135        0.5415          0.2175
# 15     M   0.500     0.400   0.130        0.6645          0.2580
# 20     M   0.355     0.280   0.095        0.2455          0.0955
# 22     F   0.565     0.440   0.155        0.9395          0.4275
# 25     F   0.560     0.440   0.140        0.9285          0.3825
# 26     F   0.580     0.450   0.185        0.9955          0.3945
# 27     M   0.590     0.445   0.140        0.9310          0.3560
# 28     M   0.605     0.475   0.180        0.9365          0.3940
# ...

# %%
data[(data['Rings'] > 15) & (data['Sex'] =='F')]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 33     F   0.680     0.550   0.175        1.7980          0.8150
# 36     F   0.540     0.475   0.155        1.2170          0.5305
# 72     F   0.595     0.475   0.170        1.2470          0.4800
# 82     F   0.520     0.425   0.165        0.9885          0.3960
# 163    F   0.725     0.560   0.210        2.1410          0.6500
# 164    F   0.650     0.545   0.230        1.7520          0.5605
# 166    F   0.725     0.575   0.175        2.1240          0.7650
# 167    F   0.680     0.570   0.205        1.8420          0.6250
# 270    F   0.640     0.525   0.215        1.7790          0.4535
# 287    F   0.495     0.400   0.155        0.6445          0.2420
# ...

# %%
#получить длину и высоту всех, у кого диаметр больше 0.5
data.loc[data['Diameter'] > 0.5, ['Length', 'Height']]
# Out:
#       Length  Height
# 31     0.680   0.165
# 32     0.665   0.165
# 33     0.680   0.175
# 34     0.705   0.200
# 81     0.620   0.175
# 94     0.695   0.190
# 95     0.665   0.195
# 128    0.700   0.160
# 129    0.710   0.165
# 142    0.650   0.190
# 152    0.635   0.190
# 163    0.725   0.210
# 164    0.650   0.230
# 165    0.725   0.190
# 166    0.725   0.175
# 167    0.680   0.205
# 168    0.705   0.220
# 169    0.680   0.175
# 170    0.695   0.215
# 181    0.640   0.175
# 184    0.645   0.200
# 232    0.625   0.215
# 258    0.635   0.170
# 270    0.640   0.215
# 273    0.630   0.225
# 274    0.630   0.155
# 275    0.655   0.215
# 276    0.660   0.185
# 278    0.635   0.205
# 291    0.565   0.210
# ...      ...     ...
# 4019   0.660   0.155
# 4020   0.680   0.175
# 4021   0.690   0.195
# 4022   0.720   0.195
# 4056   0.645   0.165
# 4057   0.690   0.185
# 4058   0.695   0.185
# 4063   0.630   0.160
# 4085   0.585   0.160
# 4094   0.630   0.175
# 4099   0.670   0.180
# ...
